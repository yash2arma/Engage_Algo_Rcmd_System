# %% [markdown]
# # Microsoft Intern Engage 2022

# %%
# importing the libraries  
import numpy as np
import pandas as pd

# %%
# Reading the data
# this csv file is having only (cast crew and movie id) data till 2017 
credits = pd.read_csv('credits.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 # Reading the data
#       2 # this csv file is having only (cast crew and movie id) data till 2017
# ----> 3 credits = pd.read_csv('credits.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'credits.csv'

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %%
# this csv file is having other movies related features data till 2017 
meta = pd.read_csv('tmdb_5000_movies.csv')

# %%
meta.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
# changing the release date from object to date time format
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
# changing the release year from object to date year format
meta['year'] = meta['release_date'].dt.year

# %%
# Counting the released number of movies in each year
meta['year'].value_counts().sort_index()
# Out:
# 1916.0      1
# 1925.0      1
# 1927.0      1
# 1929.0      2
# 1930.0      1
#          ...
# 2013.0    231
# 2014.0    238
# 2015.0    216
# 2016.0    104
# 2017.0      1
# Name: year, Length: 90, dtype: int64

# %%
# Getting only 2017 movies, as we already have movies up to the year 2016 in preprocessing_1
new_meta = meta[['id','title', 'genres', 'keywords','year', 'popularity', 'vote_average', 'vote_count']]

# %%
new_meta
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
#                                                keywords    year  popularity  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  2009.0  150.437577
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...  2007.0  139.082615
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...  2015.0  107.376788
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...  2012.0  112.312950
# 4     [{"id": 818, "name": "based on novel"}, {"id":...  2012.0   43.926995
# ...                                                 ...     ...         ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...  1992.0   14.269792
# 4799                                                 []  2011.0    0.642552
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...  2013.0    1.444476
# 4801                                                 []  2012.0    0.857008
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...  2005.0    1.929883
#
#       vote_average  vote_count
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4798           6.6         238
# 4799           5.9           5
# 4800           7.0           6
# 4801           5.7           7
# 4802           6.3          16
#
# [4803 rows x 8 columns]

# %%
new_meta.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new_meta['id'] = new_meta['id'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# merging the credits.csv data with movies_metadata.csv data on the basis on movie ID
# we are doing so , because both the files are having imformative data
data = pd.merge(new_meta, credits, on='id')

# %%
pd.set_option('display.max_colwidth', 75)
data
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4594    9367                               El Mariachi
# 4595   72766                                 Newlyweds
# 4596  231617                 Signed, Sealed, Delivered
# 4597  126186                          Shanghai Calling
# 4598   25975                         My Date with Drew
#
#                                                                           genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": ...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id":...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": ...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, ...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": ...
# ...                                                                          ...
# 4594  [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 53, ...
# 4595            [{"id": 35, "name": "Comedy"}, {"id": 10749, "name": "Romance"}]
# 4596  [{"id": 35, "name": "Comedy"}, {"id": 18, "name": "Drama"}, {"id": 1074...
# 4597                                                                          []
# 4598                                         [{"id": 99, "name": "Documentary"}]
#
#                                                                         keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"},...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "name": "drug abuse"}, {"id"...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name": "based on novel"}, {"i...
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853, "name": "crime fighter"}...
# 4     [{"id": 818, "name": "based on novel"}, {"id": 839, "name": "mars"}, {"...
# ...                                                                          ...
# 4594  [{"id": 5616, "name": "united states\u2013mexico barrier"}, {"id": 3364...
# 4595                                                                          []
# 4596  [{"id": 248, "name": "date"}, {"id": 699, "name": "love at first sight"...
# 4597                                                                          []
# 4598  [{"id": 1523, "name": "obsession"}, {"id": 2249, "name": "camcorder"}, ...
#
#         year  popularity  vote_average  vote_count  \
# 0     2009.0  150.437577           7.2       11800
# 1     2007.0  139.082615           6.9        4500
# 2     2015.0  107.376788           6.3        4466
# 3     2012.0  112.312950           7.6        9106
# 4     2012.0   43.926995           6.1        2124
# ...      ...         ...           ...         ...
# 4594  1992.0   14.269792           6.6         238
# 4595  2011.0    0.642552           5.9           5
# 4596  2013.0    1.444476           7.0           6
# 4597  2012.0    0.857008           5.7           7
# 4598  2005.0    1.929883           6.3          16
#
#                                                                             cast  \
# 0     [{'cast_id': 242, 'character': 'Jake Sully', 'credit_id': '5602a8a7c3a3...
# 1     [{'cast_id': 4, 'character': 'Captain Jack Sparrow', 'credit_id': '52fe...
# 2     [{'cast_id': 1, 'character': 'James Bond', 'credit_id': '52fe4d22c3a368...
# 3     [{'cast_id': 2, 'character': 'Bruce Wayne / Batman', 'credit_id': '52fe...
# 4     [{'cast_id': 5, 'character': 'John Carter', 'credit_id': '52fe479ac3a36...
# ...                                                                          ...
# 4594  [{'cast_id': 1, 'character': 'El Mariachi', 'credit_id': '52fe44eec3a36...
# 4595  [{'cast_id': 1, 'character': 'Buzzy', 'credit_id': '52fe487dc3a368484e0...
# 4596  [{'cast_id': 8, 'character': 'Oliver O’Toole', 'credit_id': '52fe4df3c3...
# 4597  [{'cast_id': 3, 'character': 'Sam', 'credit_id': '52fe4ad9c3a368484e16a...
# 4598  [{'cast_id': 3, 'character': 'Herself', 'credit_id': '52fe44e8c3a368484...
#
#                                                                             crew
# 0     [{'credit_id': '52fe48009251416c750aca23', 'department': 'Editing', 'ge...
# 1     [{'credit_id': '52fe4232c3a36847f800b579', 'department': 'Camera', 'gen...
# 2     [{'credit_id': '5751eed59251416b60000637', 'department': 'Production', ...
# 3     [{'credit_id': '52fe4781c3a36847f81398c3', 'department': 'Sound', 'gend...
# 4     [{'credit_id': '52fe479ac3a36847f813eaa3', 'department': 'Writing', 'ge...
# ...                                                                          ...
# 4594  [{'credit_id': '52fe44eec3a36847f80b280b', 'department': 'Directing', '...
# 4595  [{'credit_id': '52fe487dc3a368484e0fb013', 'department': 'Directing', '...
# 4596  [{'credit_id': '52fe4df3c3a36847f8275eab', 'department': 'Directing', '...
# 4597  [{'credit_id': '52fe4ad9c3a368484e16a36b', 'department': 'Directing', '...
# 4598  [{'credit_id': '58ce021b9251415a390165d9', 'department': 'Production', ...
#
# [4599 rows x 10 columns]

# %%
# evaluates an expression node or a string containing a Python literal or container display
import ast
data['keywords'] = data['keywords'].map(lambda x: ast.literal_eval(x))
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
# Extracting the geners_list using this function 
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':      # converting the "Science Fiction" to "Sci-Fi"
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0       Action Adventure Fantasy Sci-Fi
# 1              Adventure Fantasy Action
# 2                Action Adventure Crime
# 3           Action Crime Drama Thriller
# 4               Action Adventure Sci-Fi
#                      ...
# 4594              Action Crime Thriller
# 4595                     Comedy Romance
# 4596      Comedy Drama Romance TV Movie
# 4597                                NaN
# 4598                        Documentary
# Name: genres_list, Length: 4599, dtype: object

# %%
# Getting the cast information (First Cast)
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
# Getting the cast information (Second Cast)
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0            Zoe Saldana
# 1          Orlando Bloom
# 2        Christoph Waltz
# 3          Michael Caine
# 4           Lynn Collins
#               ...
# 4594      Jaime de Hoyos
# 4595         Kerry Bishé
# 4596       Kristin Booth
# 4597         Eliza Coupe
# 4598    Brian Herzlinger
# Name: actor_2_name, Length: 4599, dtype: object

# %%
# Getting the cast information (Third Cast)
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0       Sigourney Weaver
# 1        Keira Knightley
# 2            Léa Seydoux
# 3            Gary Oldman
# 4        Samantha Morton
#               ...
# 4594     Peter Marquardt
# 4595     Marsha Dietlein
# 4596        Crystal Lowe
# 4597         Bill Paxton
# 4598       Corey Feldman
# Name: actor_3_name, Length: 4599, dtype: object

# %%
# getting the Director name for Each Movie by using this function
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0                              James Cameron
# 1                             Gore Verbinski
# 2                                 Sam Mendes
# 3                          Christopher Nolan
# 4                             Andrew Stanton
#                         ...
# 4594                        Robert Rodriguez
# 4595                            Edward Burns
# 4596                             Scott Smith
# 4597                             Daniel Hsia
# 4598    Brian Herzlinger Jon Gunn Brett Winn
# Name: director_name, Length: 4599, dtype: object

# %%
# getting the keywords for Each Movie by using this function
def make_keywords_List(x):
    key = []
    st = " "
    for i in x:
        key.append(i.get('name'))
    if key == []:
        return np.NaN
    else:
        return (st.join(key))

# %%
data['keywords_list'] = data['keywords'].map(lambda x: make_keywords_List(x))

# %%
data['keywords_list']
# Out:
# 0       culture clash future space war space colony society space travel futuri...
# 1       ocean drug abuse exotic island east india trading company love of one's...
# 2       spy based on novel secret agent sequel mi6 british secret service unite...
# 3       dc comics crime fighter terrorist secret identity burglar hostage drama...
# 4       based on novel mars medallion space travel princess alien steampunk mar...
#                                            ...
# 4594                united states–mexico barrier legs arms paper knife guitar case
# 4595                                                                           NaN
# 4596           date love at first sight narration investigation team postal worker
# 4597                                                                           NaN
# 4598                                          obsession camcorder crush dream girl
# Name: keywords_list, Length: 4599, dtype: object

# %%
# making a new movie data , that is haing only this important information that we have extracted
movie = data.loc[:,['id','keywords_list','director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','popularity','vote_average','vote_count','title','year']]

# %%
movie
# Out:
#           id  \
# 0      19995
# 1        285
# 2     206647
# 3      49026
# 4      49529
# ...      ...
# 4594    9367
# 4595   72766
# 4596  231617
# 4597  126186
# 4598   25975
#
#                                                                    keywords_list  \
# 0     culture clash future space war space colony society space travel futuri...
# 1     ocean drug abuse exotic island east india trading company love of one's...
# 2     spy based on novel secret agent sequel mi6 british secret service unite...
# 3     dc comics crime fighter terrorist secret identity burglar hostage drama...
# 4     based on novel mars medallion space travel princess alien steampunk mar...
# ...                                                                          ...
# 4594              united states–mexico barrier legs arms paper knife guitar case
# 4595                                                                         NaN
# 4596         date love at first sight narration investigation team postal worker
# 4597                                                                         NaN
# 4598                                        obsession camcorder crush dream girl
#
#                              director_name     actor_1_name      actor_2_name  \
# 0                            James Cameron  Sam Worthington       Zoe Saldana
# 1                           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2                               Sam Mendes     Daniel Craig   Christoph Waltz
# 3                        Christopher Nolan   Christian Bale     Michael Caine
# 4                           Andrew Stanton    Taylor Kitsch      Lynn Collins
# ...                                    ...              ...               ...
# 4594                      Robert Rodriguez  Carlos Gallardo    Jaime de Hoyos
# 4595                          Edward Burns     Edward Burns       Kerry Bishé
# 4596                           Scott Smith      Eric Mabius     Kristin Booth
# 4597                           Daniel Hsia    Daniel Henney       Eliza Coupe
# 4598  Brian Herzlinger Jon Gunn Brett Winn   Drew Barrymore  Brian Herzlinger
#
#           actor_3_name                      genres_list  popularity  \
# 0     Sigourney Weaver  Action Adventure Fantasy Sci-Fi  150.437577
# 1      Keira Knightley         Adventure Fantasy Action  139.082615
# 2          Léa Seydoux           Action Adventure Crime  107.376788
# 3          Gary Oldman      Action Crime Drama Thriller  112.312950
# 4      Samantha Morton          Action Adventure Sci-Fi   43.926995
# ...                ...                              ...         ...
# 4594   Peter Marquardt            Action Crime Thriller   14.269792
# 4595   Marsha Dietlein                   Comedy Romance    0.642552
# 4596      Crystal Lowe    Comedy Drama Romance TV Movie    1.444476
# 4597       Bill Paxton                              NaN    0.857008
# 4598     Corey Feldman                      Documentary    1.929883
#
#       vote_average  vote_count                                     title  \
# 0              7.2       11800                                    Avatar
# 1              6.9        4500  Pirates of the Caribbean: At World's End
# 2              6.3        4466                                   Spectre
# 3              7.6        9106                     The Dark Knight Rises
# 4              6.1        2124                               John Carter
# ...            ...         ...                                       ...
# 4594           6.6         238                               El Mariachi
# 4595           5.9           5                                 Newlyweds
# 4596           7.0           6                 Signed, Sealed, Delivered
# 4597           5.7           7                          Shanghai Calling
# 4598           6.3          16                         My Date with Drew
#
#         year
# 0     2009.0
# 1     2007.0
# 2     2015.0
# 3     2012.0
# 4     2012.0
# ...      ...
# 4594  1992.0
# 4595  2011.0
# 4596  2013.0
# 4597  2012.0
# 4598  2005.0
#
# [4599 rows x 12 columns]

# %%
movie.isna().sum()
# Out:
# id                 0
# keywords_list    311
# director_name      9
# actor_1_name      20
# actor_2_name      26
# actor_3_name      33
# genres_list        9
# popularity         0
# vote_average       0
# vote_count         0
# title              0
# year               0
# dtype: int64

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# id               0
# keywords_list    0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# popularity       0
# vote_average     0
# vote_count       0
# title            0
# year             0
# dtype: int64

# %%
# renaming the columns
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})
movie = movie.rename(columns={'keywords_list':'keywords'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
# making a new column and Concatenate all the value into that single column 
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['keywords']  + movie['genres'] + movie['popularity'].map(str)

# %%
movie
# Out:
#           id  \
# 0      19995
# 1        285
# 2     206647
# 3      49026
# 4      49529
# ...      ...
# 4592  124606
# 4593   14337
# 4594    9367
# 4596  231617
# 4598   25975
#
#                                                                         keywords  \
# 0     culture clash future space war space colony society space travel futuri...
# 1     ocean drug abuse exotic island east india trading company love of one's...
# 2     spy based on novel secret agent sequel mi6 british secret service unite...
# 3     dc comics crime fighter terrorist secret identity burglar hostage drama...
# 4     based on novel mars medallion space travel princess alien steampunk mar...
# ...                                                                          ...
# 4592                                  gang audition police fake homeless actress
# 4593  distrust garage identity crisis time travel time machine mathematics in...
# 4594              united states–mexico barrier legs arms paper knife guitar case
# 4596         date love at first sight narration investigation team postal worker
# 4598                                        obsession camcorder crush dream girl
#
#                              director_name     actor_1_name      actor_2_name  \
# 0                            James Cameron  Sam Worthington       Zoe Saldana
# 1                           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2                               Sam Mendes     Daniel Craig   Christoph Waltz
# 3                        Christopher Nolan   Christian Bale     Michael Caine
# 4                           Andrew Stanton    Taylor Kitsch      Lynn Collins
# ...                                    ...              ...               ...
# 4592                       Ash Baron-Cohen   Darling Narita      Peter Greene
# 4593                         Shane Carruth    Shane Carruth    David Sullivan
# 4594                      Robert Rodriguez  Carlos Gallardo    Jaime de Hoyos
# 4596                           Scott Smith      Eric Mabius     Kristin Booth
# 4598  Brian Herzlinger Jon Gunn Brett Winn   Drew Barrymore  Brian Herzlinger
#
#           actor_3_name                           genres  popularity  \
# 0     Sigourney Weaver  Action Adventure Fantasy Sci-Fi  150.437577
# 1      Keira Knightley         Adventure Fantasy Action  139.082615
# 2          Léa Seydoux           Action Adventure Crime  107.376788
# 3          Gary Oldman      Action Crime Drama Thriller  112.312950
# 4      Samantha Morton          Action Adventure Sci-Fi   43.926995
# ...                ...                              ...         ...
# 4592   Michael Newland                            Drama    0.918116
# 4593      Casey Gooden            Sci-Fi Drama Thriller   23.307949
# 4594   Peter Marquardt            Action Crime Thriller   14.269792
# 4596      Crystal Lowe    Comedy Drama Romance TV Movie    1.444476
# 4598     Corey Feldman                      Documentary    1.929883
#
#       vote_average  vote_count                               movie_title  \
# 0              7.2       11800                                    avatar
# 1              6.9        4500  pirates of the caribbean: at world's end
# 2              6.3        4466                                   spectre
# 3              7.6        9106                     the dark knight rises
# 4              6.1        2124                               john carter
# ...            ...         ...                                       ...
# 4592           6.0           1                                      bang
# 4593           6.9         658                                    primer
# 4594           6.6         238                               el mariachi
# 4596           7.0           6                 signed, sealed, delivered
# 4598           6.3          16                         my date with drew
#
#         year  \
# 0     2009.0
# 1     2007.0
# 2     2015.0
# 3     2012.0
# 4     2012.0
# ...      ...
# 4592  1995.0
# 4593  2004.0
# 4594  1992.0
# 4596  2013.0
# 4598  2005.0
#
#                                                                             comb
# 0     Sam Worthington Zoe Saldana Sigourney Weaver James Cameron culture clas...
# 1     Johnny Depp Orlando Bloom Keira Knightley Gore Verbinski ocean drug abu...
# 2     Daniel Craig Christoph Waltz Léa Seydoux Sam Mendes spy based on novel ...
# 3     Christian Bale Michael Caine Gary Oldman Christopher Nolan dc comics cr...
# 4     Taylor Kitsch Lynn Collins Samantha Morton Andrew Stanton based on nove...
# ...                                                                          ...
# 4592  Darling Narita Peter Greene Michael Newland Ash Baron-Cohen gang auditi...
# 4593  Shane Carruth David Sullivan Casey Gooden Shane Carruth distrust garage...
# 4594  Carlos Gallardo Jaime de Hoyos Peter Marquardt Robert Rodriguez united ...
# 4596  Eric Mabius Kristin Booth Crystal Lowe Scott Smith date love at first s...
# 4598  Drew Barrymore Brian Herzlinger Corey Feldman Brian Herzlinger Jon Gunn...
#
# [4266 rows x 13 columns]

# %%
# saving the data into a csv file
movie.to_csv('holly_data_2017.csv',index=False)
