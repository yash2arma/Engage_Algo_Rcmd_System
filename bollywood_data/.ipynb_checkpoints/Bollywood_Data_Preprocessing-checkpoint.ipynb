# %%
#import libraries
# !pip install tmdbv3api
import pandas as pd
import numpy as np
from tmdbv3api import TMDb
import json
import requests
from tmdbv3api import Movie

#My TMDB API KEY
tmdb = TMDb()
tmdb.api_key = '946350b18b862d23ce1763b947a7e3e1'
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\yash sharma\anaconda33\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\yash sharma\anaconda33\lib\site-packages (from tmdbv3api) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yash sharma\anaconda33\lib\site-packages (from requests->tmdbv3api) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\yash sharma\anaconda33\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\yash sharma\anaconda33\lib\site-packages (from requests->tmdbv3api) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\yash sharma\anaconda33\lib\site-packages (from requests->tmdbv3api) (3.0.4)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\yash sharma\anaconda33\lib\site-packages)

# %% [markdown]
# ## Functions for data collection and preprocessing

# %%
#function for fetching movie id
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_id(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      return result[0].id

# %%
#function for fetching genres
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
#function for fetching keywords
 def get_keywords(x):
    keywords = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}/keywords?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['keywords']:
          keywords_str = " " 
          for i in range(0,len(data_json['keywords'])):
              keywords.append(data_json['keywords'][i]['name'])
          return keywords_str.join(keywords)
      else:
          return np.NaN

# %%
#function for fetching overview score of movie
def get_overview(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['overview']:
          return data_json['overview']
      else:
          return np.NaN

# %%
#function for fetching overview score of movie
def get_tagline(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['tagline']:
          return data_json['tagline']
      else:
          return np.NaN

# %%
#function for fetching popularity score of movie
def get_popularity(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['popularity']:
          return data_json['popularity']
      else:
          return np.NaN

# %%
#function for fetching vote average of movie
def get_vote_average(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['vote_average']:
          return data_json['vote_average']
      else:
          return np.NaN

# %%
#function for fetching popularity score of movie
def get_vote_count(x):
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['vote_count']:
          return data_json['vote_count']
      else:
          return np.NaN

# %%
#functions for fetching cast name
def get_actor1(x):
    if type(x)==float:
        return np.NaN
    return ((x.split(", ")[0]))

def get_actor2(x):
    
    if type(x)==float or len(x.split(", ")) < 2:
        return np.NaN
    else:
        return (x.split(", ")[1])

def get_actor3(x):
    if type(x)==float or len(x.split(", ")) < 3:
        return np.NaN
    else:
        return (x.split(", ")[2])

# %%
def preprocess_data(df):
    
    #if row has NULL entries we remove it from data
    df.dropna(inplace=True, thresh=11)
    
    df = df.rename(columns={'Title':'movie_title','Director': 'director', 'Genre':'genres'})
    df = df.loc[:,['id','movie_title','keywords','tagline','overview','director','actor_1','actor_2','actor_3','genres','popularity', 'year', 'vote_average','vote_count']]
    
    df['genres'] = df['genres'].replace(np.nan, 'na')
    df['overview'] = df['overview'].replace(np.nan, 'na')
    df['tagline'] = df['tagline'].replace(np.nan, 'na')
    df['keywords'] = df['keywords'].replace(np.nan, 'na')
    df['director'] = df['director'].replace(np.nan, 'unknown')
    df['actor_1'] = df['actor_1'].replace(np.nan, 'unknown')
    df['actor_2'] = df['actor_2'].replace(np.nan, 'unknown')
    df['actor_3'] = df['actor_3'].replace(np.nan, 'unknown')
    df['movie_title'] = df['movie_title'].str.lower()
    df['describe'] = df['keywords'] + ' ' + df['tagline'] + ' ' +df['overview'] + ' '+df['actor_1'] + ' ' + df['actor_2'] + ' '+ df['actor_3'] + ' '+ df['director'] +' ' + df['genres'] + ' ' + df['vote_count']
    
    return df

# %%
#function for collecting data of bollywood movies
def get_movie_data(year):
    #get movie data from wikipedia
    link = "https://en.wikipedia.org/wiki/List_of_Hindi_films_of_"+year
    df1 = pd.read_html(link, header=0)[2]
    df2 = pd.read_html(link, header=0)[3]
    df3 = pd.read_html(link, header=0)[4]
    df4 = pd.read_html(link, header=0)[5]
    df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
    
    #fetch genres, popularity of the movie through tmdb api key
    tmdb = TMDb()
    tmdb.api_key = '946350b18b862d23ce1763b947a7e3e1'
    tmdb_movie = Movie() 
    
    #fetch movie id
    df['id'] = df['Title'].map(lambda x: get_id(str(x)))
    
    #fetch keywords
    df['keywords'] = df['Title'].map(lambda x: get_keywords(str(x)))
    
    #fetch tagline
    df['tagline'] = df['Title'].map(lambda x: get_tagline(str(x)))
    
    #fetch overview
    df['overview'] = df['Title'].map(lambda x: get_overview(str(x)))
    
    #fetch Genre
    df['Genre'] = df['Title'].map(lambda x: get_genre(str(x)))
    
    #fetch poplurity
    df['popularity'] = df['Title'].map(lambda x: get_popularity(str(x)))
    
    #fetch vote average
    df['vote_average'] = df['Title'].map(lambda x: get_vote_average(str(x)))
    
    #fetch vote count
    df['vote_count'] = df['Title'].map(lambda x: get_vote_count(str(x)))
    
    #collect required features
    df = df[['id','Title','keywords', 'tagline', 'overview','Director','Cast','Genre','popularity', 'vote_average', 'vote_count']]
    
    #add actors name and release year of the movie
    df['actor_1'] = df['Cast'].map(lambda x: get_actor1(x))
    df['actor_2'] = df['Cast'].map(lambda x: get_actor2(x))
    df['actor_3'] = df['Cast'].map(lambda x: get_actor3(x))
    df['year'] = year
    
    #data preprocess
    data = preprocess_data(df)
    
    return data

# %% [markdown]
# ## Collecting Movies data released after 2000

# %%
#collecting movies of 2000
data = get_movie_data('2000')
# Out:
# C:\Users\Yash Sharma\Anaconda33\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
#collecting movies of 2001
data_2001 = get_movie_data('2001')
data = data.append(data_2001,ignore_index=True)

# %%
#collecting movies of 2002
data_2002 = get_movie_data('2002')
data = data.append(data_2002,ignore_index=True)

# %%
#collecting movies of 2003
data_2003 = get_movie_data('2003')
data = data.append(data_2003,ignore_index=True)

# %%
#collecting movies of 2004
data_2004 = get_movie_data('2004')
data = data.append(data_2004,ignore_index=True)

# %%
#collecting movies of 2005
data_2005 = get_movie_data('2005')
data = data.append(data_2005,ignore_index=True)

# %%
#collecting movies of 2006
data_2006 = get_movie_data('2006')
data = data.append(data_2006,ignore_index=True)

# %%
#collecting movies of 2007
data_2007 = get_movie_data('2007')
data = data.append(data_2007,ignore_index=True)

# %%
#collecting movies of 2008
data_2008 = get_movie_data('2008')
data = data.append(data_2008,ignore_index=True)

# %%
#collecting movies of 2009
data_2009 = get_movie_data('2009')
data = data.append(data_2009,ignore_index=True)

# %%
#collecting movies of 2010
data_2010 = get_movie_data('2010')
data = data.append(data_2010,ignore_index=True)

# %%
#collecting movies of 2011
data_2011 = get_movie_data('2011')
data = data.append(data_2011,ignore_index=True)

# %%
#collecting movies of 2012
data_2012 = get_movie_data('2012')
data = data.append(data_2012,ignore_index=True)

# %%
#collecting movies of 2013
data_2013 = get_movie_data('2013')
data = data.append(data_2013,ignore_index=True)

# %%
#collecting movies of 2014
data_2014 = get_movie_data('2014')
data = data.append(data_2014,ignore_index=True)

# %%
#collecting movies of 2015
data_2015 = get_movie_data('2015')
data = data.append(data_2015,ignore_index=True)

# %%
#collecting movies of 2016
data_2016 = get_movie_data('2016')
data = data.append(data_2016,ignore_index=True)

# %%
#collecting movies of 2017
data_2017 = get_movie_data('2017')
data = data.append(data_2017,ignore_index=True)

# %%
#collecting movies of 2018
data_2018 = get_movie_data('2018')
data = data.append(data_2018,ignore_index=True)

# %%
#collecting movies of 2019
data_2019 = get_movie_data('2019')
data = data.append(data_2019,ignore_index=True)

# %%
#collecting movies of 2020
data_2020 = get_movie_data('2020')
data = data.append(data_2020,ignore_index=True)

# %%
#collecting movies of 2021
data_2021 = get_movie_data('2021')
data = data.append(data_2021,ignore_index=True)

# %%
#collecting movies of 2022
data_2022 = get_movie_data('2022')
data = data.append(data_2022,ignore_index=True)

# %%
data
# Out:
#                    movie_title                director          actor_1  \
# 0           kuch kuch hota hai             Karan Johar    Shahrukh Khan
# 1                      bichhoo            Guddu Dhanoa       Bobby Deol
# 2                      bulandi       Rama Rao Tatineni      Rajinikanth
# 3               chal mere bhai            David Dhawan      Sanjay Dutt
# 4                      dhadkan        Dharmesh Darshan     Akshay Kumar
# ...                        ...                     ...              ...
# 1023   a daughter's tale pankh                Premraaj  Nishigandha Wad
# 1024                kadvi hawa       Nila Madhab Panda    Sanjay Mishra
# 1025            fukrey returns   Mrighdeep Singh Lamba    Pulkit Samrat
# 1026                 game over  Paresh Vinodray Savani    Rajesh Sharma


# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                              Thriller Drama
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 237  Animation Action Adventure Comedy Family
# 238                             Drama Romance
# 239                 War Drama Action Thriller
# 240                       Drama Crime History
# 241                                     Drama
#
# [242 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Yash Sharma\Anaconda33\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Yash Sharma\Anaconda33\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Yash Sharma\Anaconda33\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan                            Thriller Drama
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 237     Rashida Jones  Animation Action Adventure Comedy Family
# 238     Florence Pugh                             Drama Romance
# 239       Mark Strong                 War Drama Action Thriller
# 240       Brie Larson                       Drama Crime History
# 241       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 237  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
#
sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5873  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5874            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5875              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5876   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5877         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5873         Rashida Jones  Animation Action Adventure Comedy Family
# 5874         Florence Pugh                             Drama Romance
# 5875           Mark Strong                 War Drama Action Thriller
# 5876           Brie Larson                       Drama Crime History
# 5877           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5873                                  spies in disguise
# 5874                                       little women
# 5875                                               1917
# 5876                                         just mercy
# 5877                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5873  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5874  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5875  George MacKay Dean-Charles Chapman Mark Strong...
# 5876  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5877  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5878 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# comb             1
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('datasets/data_2019.csv',index=False)

# %%
link = "https://en.wikipedia.org/wiki/List_of_Hindi_films_of_"+'2000'
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yash Sharma\Anaconda33\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df
# Out:
#     Cast Director Genre                                      Hindi cinema  \
# 0    NaN      NaN   NaN                                             1920s
# 1    NaN      NaN   NaN  1920 1921 1922 1923 19241925 1926 1927 1928 1929
# 2    NaN      NaN   NaN                                             1930s
# 3    NaN      NaN   NaN  1930 1931 1932 1933 19341935 1936 1937 1938 1939
# 4    NaN      NaN   NaN                                             1940s
# ..   ...      ...   ...                                               ...
# 125  NaN      NaN   NaN                                               NaN
# 126  NaN      NaN   NaN                                               NaN
# 127  NaN      NaN   NaN                                               NaN
# 128  NaN      NaN   NaN                                               NaN
# 129  NaN      NaN   NaN                                               NaN
#
#     Music director  Rank Title vteIndian films by year and decade  \
# 0              NaN   NaN   NaN                                NaN
# 1              NaN   NaN   NaN                                NaN
# 2              NaN   NaN   NaN                                NaN
# 3              NaN   NaN   NaN                                NaN
# 4              NaN   NaN   NaN                                NaN
# ..             ...   ...   ...                                ...
# 125            NaN   NaN   NaN                               Odia
# 126            NaN   NaN   NaN                              Tamil
# 127            NaN   NaN   NaN                             Telugu
# 128            NaN   NaN   NaN                              Other
# 129            NaN   NaN   NaN                            Related
#
#                   vteIndian films by year and decade.1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 125  1936 1949 1950 1951 1953 1954 1956 1959 1960 1...
# 126  1930s 1940 1941 1942 1943 1944 1945 1946 1947 ...
# 127  1930s 1940 1941 1942 1943 1944 1945 1946 1947 ...
# 128                                   Assamese Punjabi
# 129                        Silent films of South India
#
# [130 rows x 9 columns]
